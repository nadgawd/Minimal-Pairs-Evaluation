# %%
import math
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import numpy as np
import pandas as pd

# %%
def calculate_sentence_log_prob(model, tokenizer, sentence, device):
    inputs = tokenizer(sentence, return_tensors="pt").to(device)

    with torch.no_grad():
        outputs = model(**inputs, labels=inputs["input_ids"])

    loss = outputs.loss.item() # -mean(log_prob)
    num_tokens = inputs["input_ids"].shape[1]

    sentence_log_prob = -loss * (num_tokens - 1)

    perplexity = math.exp(loss)

    return sentence_log_prob, perplexity

# %%
model_id = "Qwen/Qwen2.5-7B"
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Loading {model_id}...")
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    device_map="auto",
    torch_dtype=torch.float16,
    trust_remote_code=True
)
# Out:
# Loading Qwen/Qwen2.5-7B...
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/138 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %% [markdown]
# ### Testing on Animate Subject Passive

# %%
data1 = pd.read_csv("data/animate_subject_passive.csv")
# data

for index, row in data1.iterrows():
  s1 = row["rows__row__sentence_good"]
  s2 = row["rows__row__sentence_bad"]

  log_prob_s1, ppl_s1 = calculate_sentence_log_prob(model, tokenizer, s1, device)
  log_prob_s2, ppl_s2 = calculate_sentence_log_prob(model, tokenizer, s2, device)

  data1.loc[index, "log(P(S1))"] = log_prob_s1
  data1.loc[index, "log(P(S2))"] = log_prob_s2

  if log_prob_s1 > log_prob_s2:
      data1.loc[index, "log(P(S1)) > log(P(S2))"] = 1
  else:
      data1.loc[index, "log(P(S1)) > log(P(S2))"] = 0
  data1.loc[index, "Confidence"] = abs(log_prob_s1 - log_prob_s2)
  data1.loc[index, "Ppl(S1)"] = ppl_s1
  data1.loc[index, "Ppl(S2)"] = ppl_s2

# %%
data1
# Out:
#                             rows__row__sentence_good  \
# 0           Amanda was respected by some waitresses.
# 1             Some lake was passed by some cashiers.
# 2                       Lisa was kissed by the boys.
# 3            Amanda isn't respected by the children.
# 4               The glove was noticed by some woman.
# ..                                               ...
# 95  All public parks were explored by some teenager.
# 96             This cake is seen by the pedestrians.
# 97   Every person wasn't cared for by the offspring.
# 98            Edward wasn't insulted by some alumni.
# 99           Brad was investigated by the actresses.
#
#                            rows__row__sentence_bad  log(P(S1))  log(P(S2))  \
# 0            Amanda was respected by some picture.  -48.375786  -49.595264
# 1          Some lake was passed by some phenomena.  -50.271557  -48.479364
# 2                  Lisa was kissed by the blouses.  -33.266919  -43.129505
# 3              Amanda isn't respected by the cups.  -43.473186  -54.326721
# 4             The glove was noticed by some mouse.  -42.396571  -48.205002
# ..                                             ...         ...         ...
# 95  All public parks were explored by some screen.  -46.516441  -52.905529
# 96           This cake is seen by the parentheses.  -41.153308  -42.421058
# 97    Every person wasn't cared for by the fungus.  -48.228079  -46.305618
# 98            Edward wasn't insulted by some oxen.  -47.677170  -52.561508
# 99           Brad was investigated by the rabbits.  -38.832747  -35.088080
#
#     log(P(S1)) > log(P(S2))  Confidence     Ppl(S1)      Ppl(S2)
# 0                       1.0    1.219478  422.831278  1193.968257
# 1                       0.0    1.792193  535.898409  1018.028728
# 2                       1.0    9.862586  255.823185   474.071370
# 3                       1.0   10.853535  229.097645   889.660695
# 4                       1.0    5.808431  426.944071   978.899355
# ..                      ...         ...         ...          ...
# 95                      1.0    6.389088  335.142283   744.856161
# 96                      1.0    1.267749  357.467360   428.440169
# 97                      0.0    1.922462  212.443374   171.583263
# 98                      1.0    4.884338  387.473022   343.836936
# 99                      0.0    3.744667  646.856564   346.545250
#
# [100 rows x 8 columns]

# %%
data1.to_csv("outputs/animate_subject_passive_output.csv", index=False)

# %% [markdown]
# ### Testing on Animate Subject Trans

# %%
data2 = pd.read_csv("data/animate_subject_trans.csv")

for index, row in data2.iterrows():
  s1 = row["rows__row__sentence_good"]
  s2 = row["rows__row__sentence_bad"]

  log_prob_s1, ppl_s1 = calculate_sentence_log_prob(model, tokenizer, s1, device)
  log_prob_s2, ppl_s2 = calculate_sentence_log_prob(model, tokenizer, s2, device)

  data2.loc[index, "log(P(S1))"] = log_prob_s1
  data2.loc[index, "log(P(S2))"] = log_prob_s2

  if log_prob_s1 > log_prob_s2:
      data2.loc[index, "log(P(S1)) > log(P(S2))"] = 1
  else:
      data2.loc[index, "log(P(S1)) > log(P(S2))"] = 0
  data2.loc[index, "Confidence"] = abs(log_prob_s1 - log_prob_s2)
  data2.loc[index, "Ppl(S1)"] = ppl_s1
  data2.loc[index, "Ppl(S2)"] = ppl_s2

# %%
data2
# Out:
#                       rows__row__sentence_good  \
# 0                      Tina revealed Margaret.
# 1                      Danielle visited Irene.
# 2          Paul runs around the art galleries.
# 3             Most banks have praised Raymond.
# 4   Every doctor was selling some restaurants.
# ..                                         ...
# 95                    Lawrence fled from Brad.
# 96  These dancers should investigate Caroline.
# 97        Mitchell can't complain about Peter.
# 98     Every doctor wasn't describing a river.
# 99                    Sally concealed Kirsten.
#
#                      rows__row__sentence_bad  log(P(S1))  log(P(S2))  \
# 0               The horse revealed Margaret.  -37.472755  -42.783928
# 1                     The eye visited Irene.  -29.353811  -37.865490
# 2   The river runs around the art galleries.  -35.600347  -39.867378
# 3          The jackets have praised Raymond.  -40.006485  -49.231129
# 4        A cup was selling some restaurants.  -45.542121  -48.436804
# ..                                       ...         ...         ...
# 95                Literature fled from Brad.  -31.858149  -38.442085
# 96     Glaciers should investigate Caroline.  -44.382057  -48.820421
# 97   This window can't complain about Peter.  -36.565186  -44.745667
# 98     This story wasn't describing a river.  -48.002614  -38.636765
# 99              This beef concealed Kirsten.  -40.110068  -55.942931
#
#     log(P(S1)) > log(P(S2))  Confidence       Ppl(S1)       Ppl(S2)
# 0                       1.0    5.311172  11709.887601  44177.989962
# 1                       1.0    8.511679   1538.330192  12917.942171
# 2                       1.0    4.267031    377.432254    297.477824
# 3                       1.0    9.224644   2984.826789  18886.935876
# 4                       1.0    2.894683   1979.012949   3206.068299
# ..                      ...         ...           ...           ...
# 95                      1.0    6.583936    585.010453   2182.916177
# 96                      1.0    4.438364   7161.046711   3417.747098
# 97                      1.0    8.180481    185.600776    597.191684
# 98                      0.0    9.365849    951.002117    249.519714
# 99                      1.0   15.832863   3047.307413  72300.493587
#
# [100 rows x 8 columns]

# %%
data2.to_csv("outputs/animate_subject_trans_output.csv", index=False)

# %% [markdown]
# ### Testing on Self Curated Data

# %%
data3 = pd.read_csv("data/Self_curated_data.csv")

for index, row in data3.iterrows():
  s1 = row["rows__row__sentence_good"]
  s2 = row["rows__row__sentence_bad"]

  log_prob_s1, ppl_s1 = calculate_sentence_log_prob(model, tokenizer, s1, device)
  log_prob_s2, ppl_s2 = calculate_sentence_log_prob(model, tokenizer, s2, device)

  data3.loc[index, "log(P(S1))"] = log_prob_s1
  data3.loc[index, "log(P(S2))"] = log_prob_s2

  if log_prob_s1 > log_prob_s2:
      data3.loc[index, "log(P(S1)) > log(P(S2))"] = 1
  else:
      data3.loc[index, "log(P(S1)) > log(P(S2))"] = 0
  data3.loc[index, "Confidence"] = abs(log_prob_s1 - log_prob_s2)
  data3.loc[index, "Ppl(S1)"] = ppl_s1
  data3.loc[index, "Ppl(S2)"] = ppl_s2

# %%
data3
# Out:
#              rows__row__sentence_good             rows__row__sentence_bad  \
# 0                I eat poha with tea                 I eat plate with tea
# 1                  I ordered a cycle                     I ordered a wall
# 2                    I gave him water                      I gave him air
# 3                     I eat a tablet                       I eat an ipad
# 4     I and he  drank coffee together  I and he drank coffee mug together
# 5  He has 10 lakh ruppes in his bank     He has 10 lakh cars  in his bank
# 6     He has calculator in his phone             He has car in his phone
#
#    log(P(S1))  log(P(S2))  log(P(S1)) > log(P(S2))  Confidence      Ppl(S1)  \
# 0  -39.645988  -34.018814                      0.0    5.627173   740.751036
# 1  -24.988827  -19.718000                      0.0    5.270827   516.567872
# 2  -19.915164  -21.711063                      1.0    1.795898   763.862773
# 3  -30.308693  -34.257122                      1.0    3.948429  1953.100196
# 4  -39.351949  -48.937311                      1.0    9.585362   705.324600
# 5  -46.007569  -51.244316                      1.0    5.236747    46.245498
# 6  -37.958808  -38.596733                      1.0    0.637925   559.178080
#
#        Ppl(S2)
# 0  4937.940013
# 1   715.274686
# 2  1389.947102
# 3  5241.067668
# 4  3484.983291
# 5   168.078580
# 6   621.905933

# %%
data3.to_csv("outputs/Self_curated_data_output.csv", index=False)

# %% [markdown]
# ### Testing on Reference Tracking Data

# %%
data4 = pd.read_csv("data/Reference_tracking_data.csv")

for index, row in data4.iterrows():
  s1 = row["rows__row__sentence_good"]
  s2 = row["rows__row__sentence_bad"]

  log_prob_s1, ppl_s1 = calculate_sentence_log_prob(model, tokenizer, s1, device)
  log_prob_s2, ppl_s2 = calculate_sentence_log_prob(model, tokenizer, s2, device)

  data4.loc[index, "log(P(S1))"] = log_prob_s1
  data4.loc[index, "log(P(S2))"] = log_prob_s2

  if log_prob_s1 > log_prob_s2:
      data4.loc[index, "log(P(S1)) > log(P(S2))"] = 1
  else:
      data4.loc[index, "log(P(S1)) > log(P(S2))"] = 0
  data4.loc[index, "Confidence"] = abs(log_prob_s1 - log_prob_s2)
  data4.loc[index, "Ppl(S1)"] = ppl_s1
  data4.loc[index, "Ppl(S2)"] = ppl_s2

# %%
data4
# Out:
#                              rows__row__sentence_good  \
# 0    Riya gave Anu a gift because she had a birthday.
# 1   Arjun called Kabir because he needed help with...
# 2          Meera hugged Sanya because she was crying.
# 3   The dog barked at the stranger because he ente...
# 4   Amit cleaned the table because it had food sta...
# 5   Tina put the book in the bag because it was to...
# 6   Rohan thanked Neeraj because he fixed the comp...
# 7   Priya covered the pot because it was boiling o...
# 8   The car hit the pole because it slipped on the...
# 9        Anita washed the spoon because it was dirty.
# 10  Aman moved the chair because it was blocking t...
# 11  Sneha closed the window because it was letting...
# 12  The wind shook the tree because it was strong ...
# 13  Kabir threw the ball because it slipped from h...
# 14            Ritu fed the cat because it was hungry.
# 15  The teacher scolded the student because he was...
# 16  Ayesha put the towel in the sun because it was...
# 17  Raghav carried the box because it was too heav...
# 18  The monkey dropped the fruit because it was sl...
# 19    Mehul stopped the bike because it was skidding.
# 20  The bottle broke the tile because it fell from...
# 21      Ria stitched the shirt because it had a tear.
# 22  The chef covered the pan because it was splash...
# 23  Lakshya pushed the trolley because it was bloc...
# 24   The candle melted the toy because it touched it.
# 25      Arnav mopped the floor because it was sticky.
# 26    Simran saved the file because it was important.
# 27        The child cried because the balloon popped.
# 28  Nisha opened the umbrella because it was raining.
# 29  The cup fell from the table because it was sha...
# 30    Rohan moved the lamp because it was flickering.
# 31  Aditi shifted the crate because it was blockin...
# 32  The ball rolled into the drain because it was ...
# 33  Sarthak moved the fan because it was too close...
# 34  The cat chased the mouse because it ran under ...
# 35  Meera pressed the button because it wasn’t wor...
# 36  The truck splashed the pedestrian because it w...
# 37  Karan covered the bowl because it was attracti...
# 38  The wind blew the papers because they were light.
# 39  Asha closed the drawer because it was sticking...
# 40  The mechanic fixed the bike because it had a l...
# 41  Piyush dried the bench because it was wet from...
# 42  The clock woke the child because it was too loud.
# 43  Sana pushed the trolley because it was blockin...
# 44  The dog avoided the bucket because it was slip...
# 45  Ananya folded the blanket because it was wrink...
# 46        The laptop shut down because it overheated.
# 47      Ravi cleaned the mirror because it was dusty.
# 48     The bus stopped because it reached the signal.
# 49  The bulb fused because it received a voltage s...
#
#                               rows__row__sentence_bad  log(P(S1))  log(P(S2))  \
# 0      Riya gave Anu a gift because she had a basket.  -42.745728  -55.667061
# 1   Arjun called Kabir because the project needed ...  -42.675270  -59.629595
# 2   Meera hugged Sanya because the hallway was cry...  -43.265847  -65.775862
# 3   The dog barked at the stranger because the gat...  -41.357240  -56.148956
# 4   Amit cleaned the table because the food stains...  -48.670402  -67.405380
# 5   Tina put the book in the bag because the bag w...  -39.566331  -46.236568
# 6   Rohan thanked Neeraj because the computer fixe...  -41.333451  -55.868119
# 7   Priya covered the pot because the boiling wate...  -39.455934  -55.551338
# 8   The car hit the pole because the pole slipped ...  -41.626479  -51.660686
# 9       Anita washed the spoon because she was dirty.  -44.449087  -51.854722
# 10  Aman moved the chair because the door was bloc...  -45.675346  -50.409231
# 11  Sneha closed the window because the dust was l...  -50.447814  -70.354321
# 12  The wind shook the tree because the tree was s...  -45.163980  -53.078344
# 13  Kabir threw the ball because his hand slipped ...  -48.172325  -53.046167
# 14      Ritu fed the cat because the food was hungry.  -39.576895  -54.044023
# 15  The teacher scolded the student because the cl...  -33.612931  -47.183853
# 16  Ayesha put the towel in the sun because the su...  -49.240821  -60.166918
# 17  Raghav carried the box because his sister was ...  -41.912601  -52.117104
# 18  The monkey dropped the fruit because the tree ...  -41.783692  -45.781531
# 19  Mehul stopped the bike because the road was sk...  -49.083231  -53.401600
# 20  The bottle broke the tile because the tile fel...  -46.763386  -53.220491
# 21  Ria stitched the shirt because the tear had a ...  -50.112677  -69.477065
# 22  The chef covered the pan because the oil was c...  -47.354599  -61.850990
# 23  Lakshya pushed the trolley because the exit wa...  -51.326091  -62.631180
# 24  The candle melted the toy because the toy touc...  -54.717802  -56.946869
# 25      Arnav mopped the floor because he was sticky.  -43.204317  -49.909906
# 26  Simran saved the file because the importance s...  -50.014482  -71.928663
# 27          The child cried because the child popped.  -34.381111  -43.408540
# 28  Nisha opened the umbrella because the rain ope...  -35.452458  -55.502005
# 29  The cup fell from the table because the table ...  -43.699112  -67.619885
# 30    Rohan moved the lamp because he was flickering.  -43.738861  -47.101164
# 31  Aditi shifted the crate because the path was b...  -51.220213  -63.740160
# 32  The ball rolled into the drain because the dra...  -46.471406  -52.050551
# 33  Sarthak moved the fan because the curtain was ...  -54.408291  -61.675050
# 34  The cat chased the mouse because the sofa ran ...  -46.694616  -61.411743
# 35  Meera pressed the button because she wasn’t wo...  -43.599059  -49.063426
# 36  The truck splashed the pedestrian because the ...  -52.079885  -62.469908
# 37  Karan covered the bowl because the flies were ...  -58.089423  -66.902464
# 38  The wind blew the papers because the wind was ...  -42.482556  -45.580149
# 39  Asha closed the drawer because she was stickin...  -55.338392  -56.856031
# 40  The mechanic fixed the bike because the chain ...  -45.653935  -60.034447
# 41  Piyush dried the bench because the rain dried ...  -47.748279  -60.065765
# 42  The clock woke the child because the child was...  -38.795090  -45.765354
# 43  Sana pushed the trolley because the aisle was ...  -45.401493  -53.449659
# 44  The dog avoided the bucket because the bucket ...  -42.287210  -51.814768
# 45  Ananya folded the blanket because she was wrin...  -50.026407  -55.378809
# 46  The laptop shut down because the table overhea...  -36.475433  -54.723257
# 47  Ravi cleaned the mirror because the dust clean...  -38.923445  -50.612192
# 48     The bus stopped because the signal reached it.  -36.086052  -42.056694
# 49  The bulb fused because the spike received a bulb.  -58.877329  -75.450016
#
#     log(P(S1)) > log(P(S2))  Confidence     Ppl(S1)      Ppl(S2)
# 0                       1.0   12.921332   35.238669   103.432760
# 1                       1.0   16.954325   35.032371   143.902056
# 2                       1.0   22.510015  122.402685   718.802170
# 3                       1.0   14.791716   31.388345    75.124779
# 4                       1.0   18.734979  129.935758   275.094595
# 5                       1.0    6.670238   13.981785    17.989451
# 6                       1.0   14.534667   42.844894   160.600496
# 7                       1.0   16.095405   51.707010   102.440094
# 8                       1.0   10.034206   32.100553    53.191515
# 9                       1.0    7.405635  139.600875   317.867866
# 10                      1.0    4.733885   63.580332    97.773867
# 11                      1.0   19.906507   36.723440   108.884541
# 12                      1.0    7.914365   91.505397   124.624352
# 13                      1.0    4.873842   55.387860    59.173534
# 14                      1.0   14.467127   81.242037   222.383252
# 15                      1.0   13.570922   21.236492    51.008269
# 16                      1.0   10.926096   44.157178    73.525846
# 17                      1.0   10.204503   19.960538    41.373902
# 18                      1.0    3.997839  103.817286    97.334464
# 19                      1.0    4.318368   86.670359    85.638361
# 20                      1.0    6.457106   70.190775    84.355579
# 21                      1.0   19.364388  150.094885   553.408697
# 22                      1.0   14.496391   74.066519   173.165744
# 23                      1.0   11.305089   39.101052    87.676657
# 24                      1.0    2.229067  436.922478   297.283696
# 25                      1.0    6.705589   75.221095   147.082057
# 26                      1.0   21.914181  259.087196  1329.909702
# 27                      1.0    9.027430  135.854877   493.350579
# 28                      1.0   20.049546   51.375531   257.289128
# 29                      1.0   23.920774   79.036612   125.209936
# 30                      1.0    3.362303   79.351401   111.065086
# 31                      1.0   12.519946  105.254691   328.507594
# 32                      1.0    5.579145   68.352167   113.507427
# 33                      1.0    7.266758   48.730569    81.888675
# 34                      1.0   14.717127   69.753324   166.941803
# 35                      1.0    5.464367   52.643923    86.514447
# 36                      1.0   10.390023   54.934689    86.672467
# 37                      1.0    8.813041  333.266449   263.803716
# 38                      1.0    3.097593  112.200111    95.393922
# 39                      1.0    1.517639  253.113809   294.595474
# 40                      1.0   14.380512   63.456696   148.839800
# 41                      1.0   12.317486   39.367655   235.220667
# 42                      1.0    6.970264   48.400443    64.102714
# 43                      1.0    8.048166   43.967809    85.982026
# 44                      1.0    9.527558  109.791030    75.030697
# 45                      1.0    5.352402  148.805595   254.138882
# 46                      1.0   18.247823   95.528933   437.187359
# 47                      1.0   11.688747   75.552456   157.782770
# 48                      1.0    5.970642   90.990626   191.921561
# 49                      1.0   16.572687  693.620812  4373.570985

# %%
data4.to_csv("outputs/Reference_tracking_data.csv.csv", index=False)
