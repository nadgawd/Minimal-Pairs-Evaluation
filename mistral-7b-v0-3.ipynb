# %%
import math
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
import numpy as np
import pandas as pd

# %%
def calculate_sentence_log_prob(model, tokenizer, sentence, device):
    inputs = tokenizer(sentence, return_tensors="pt").to(device)
    
    with torch.no_grad():
        outputs = model(**inputs, labels=inputs["input_ids"])
    
    loss = outputs.loss.item() # -mean(log_prob)
    num_tokens = inputs["input_ids"].shape[1]
    
    sentence_log_prob = -loss * (num_tokens - 1)

    perplexity = math.exp(loss)
    
    return sentence_log_prob, perplexity

# %%
model_id = "mistralai/Mistral-7B-v0.3"
device = "cuda" if torch.cuda.is_available() else "cpu"

print(f"Loading {model_id}...")
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_id, 
    device_map="auto", 
    torch_dtype=torch.float16, 
    trust_remote_code=True
)
# Out:
# Loading mistralai/Mistral-7B-v0.3...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# 2025-12-02 11:52:33.547191: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764676353.739292      47 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764676353.793360      47 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.55G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.95G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]

# %% [markdown]
# ### Testing on Animate Subject Passive

# %%
data1 = pd.read_csv("/kaggle/input/dataset/animate_subject_passive.csv")

for index, row in data1.iterrows():
  s1 = row["rows__row__sentence_good"]         
  s2 = row["rows__row__sentence_bad"]   

  log_prob_s1, ppl_s1 = calculate_sentence_log_prob(model, tokenizer, s1, device)
  log_prob_s2, ppl_s2 = calculate_sentence_log_prob(model, tokenizer, s2, device)

  data1.loc[index, "log(P(S1))"] = log_prob_s1
  data1.loc[index, "log(P(S2))"] = log_prob_s2

  if log_prob_s1 > log_prob_s2:
      data1.loc[index, "log(P(S1)) > log(P(S2))"] = 1
  else:
      data1.loc[index, "log(P(S1)) > log(P(S2))"] = 0
  data1.loc[index, "Confidence"] = abs(log_prob_s1 - log_prob_s2)
  data1.loc[index, "Ppl(S1)"] = ppl_s1
  data1.loc[index, "Ppl(S2)"] = ppl_s2

# %%
data1
# Out:
#                             rows__row__sentence_good  \
# 0           Amanda was respected by some waitresses.
# 1             Some lake was passed by some cashiers.
# 2                       Lisa was kissed by the boys.
# 3            Amanda isn't respected by the children.
# 4               The glove was noticed by some woman.
# ..                                               ...
# 95  All public parks were explored by some teenager.
# 96             This cake is seen by the pedestrians.
# 97   Every person wasn't cared for by the offspring.
# 98            Edward wasn't insulted by some alumni.
# 99           Brad was investigated by the actresses.
#
#                            rows__row__sentence_bad  log(P(S1))  log(P(S2))  \
# 0            Amanda was respected by some picture.  -53.197736  -56.755071
# 1          Some lake was passed by some phenomena.  -61.211786  -60.220716
# 2                  Lisa was kissed by the blouses.  -39.273139  -47.158657
# 3              Amanda isn't respected by the cups.  -46.116250  -54.106533
# 4             The glove was noticed by some mouse.  -47.391754  -50.890230
# ..                                             ...         ...         ...
# 95  All public parks were explored by some screen.  -54.611351  -60.268464
# 96           This cake is seen by the parentheses.  -44.630265  -48.117137
# 97    Every person wasn't cared for by the fungus.  -54.526314  -56.067416
# 98            Edward wasn't insulted by some oxen.  -58.021603  -58.304277
# 99           Brad was investigated by the rabbits.  -47.464550  -45.564732
#
#     log(P(S1)) > log(P(S2))  Confidence     Ppl(S1)      Ppl(S2)
# 0                       1.0    3.557334  369.023226  3320.488670
# 1                       0.0    0.991070  899.023870   805.280545
# 2                       1.0    7.885519  273.266733   363.155869
# 3                       1.0    7.990283  168.010710   408.232557
# 4                       1.0    3.498476  193.591527   285.565084
# ..                      ...         ...         ...          ...
# 95                      1.0    5.657114  431.785025   809.564145
# 96                      1.0    3.486872   86.749662   122.942122
# 97                      1.0    1.541102   94.053097    74.655047
# 98                      1.0    0.282674  125.855390   200.414719
# 99                      0.0    1.899818  377.310612   297.552729
#
# [100 rows x 8 columns]

# %%
data1.to_csv("/kaggle/working/animate_subject_passive_output.csv")

# %% [markdown]
# ### Testing Animate Subject Trans

# %%
data2 = pd.read_csv("/kaggle/input/dataset/animate_subject_trans.csv")

for index, row in data2.iterrows():
  s1 = row["rows__row__sentence_good"]         
  s2 = row["rows__row__sentence_bad"]   

  log_prob_s1, ppl_s1 = calculate_sentence_log_prob(model, tokenizer, s1, device)
  log_prob_s2, ppl_s2 = calculate_sentence_log_prob(model, tokenizer, s2, device)

  data2.loc[index, "log(P(S1))"] = log_prob_s1
  data2.loc[index, "log(P(S2))"] = log_prob_s2

  if log_prob_s1 > log_prob_s2:
      data2.loc[index, "log(P(S1)) > log(P(S2))"] = 1
  else:
      data2.loc[index, "log(P(S1)) > log(P(S2))"] = 0
  data2.loc[index, "Confidence"] = abs(log_prob_s1 - log_prob_s2)
  data2.loc[index, "Ppl(S1)"] = ppl_s1
  data2.loc[index, "Ppl(S2)"] = ppl_s2

# %%
data2
# Out:
#                       rows__row__sentence_good  \
# 0                      Tina revealed Margaret.
# 1                      Danielle visited Irene.
# 2          Paul runs around the art galleries.
# 3             Most banks have praised Raymond.
# 4   Every doctor was selling some restaurants.
# ..                                         ...
# 95                    Lawrence fled from Brad.
# 96  These dancers should investigate Caroline.
# 97        Mitchell can't complain about Peter.
# 98     Every doctor wasn't describing a river.
# 99                    Sally concealed Kirsten.
#
#                      rows__row__sentence_bad  log(P(S1))  log(P(S2))  \
# 0               The horse revealed Margaret.  -43.118892  -41.896906
# 1                     The eye visited Irene.  -39.424081  -44.196545
# 2   The river runs around the art galleries.  -42.273653  -42.069731
# 3          The jackets have praised Raymond.  -48.500696  -49.248203
# 4        A cup was selling some restaurants.  -53.299371  -52.008657
# ..                                       ...         ...         ...
# 95                Literature fled from Brad.  -45.431013  -45.346725
# 96     Glaciers should investigate Caroline.  -51.727142  -51.303811
# 97   This window can't complain about Peter.  -45.051517  -52.385679
# 98     This story wasn't describing a river.  -55.198686  -44.859190
# 99              This beef concealed Kirsten.  -45.612252  -57.666248
#
#     log(P(S1)) > log(P(S2))  Confidence      Ppl(S1)      Ppl(S2)
# 0                       0.0    1.221986  5562.363257  4356.312318
# 1                       1.0    4.772464   713.855201  1581.439480
# 2                       0.0    0.203922   109.625773    67.152965
# 3                       1.0    0.747507  3240.391270  1136.214738
# 4                       0.0    1.290714  2026.764227  1685.484165
# ..                      ...         ...          ...          ...
# 95                      0.0    0.084289  8832.581632  1915.602394
# 96                      0.0    0.423331  1619.044912  1524.033729
# 97                      1.0    7.334162   279.063592   337.184759
# 98                      0.0   10.339495   460.902855   146.109230
# 99                      1.0   12.053996   675.893848  1350.568698
#
# [100 rows x 8 columns]

# %%
data2.to_csv("/kaggle/working/animate_subject_trans_output.csv")

# %% [markdown]
# ### Testing on Self Curated Data

# %%
data3 = pd.read_csv("/kaggle/input/dataset/Self_curated_data.csv")

for index, row in data3.iterrows():
  s1 = row["rows__row__sentence_good"]         
  s2 = row["rows__row__sentence_bad"]   

  log_prob_s1, ppl_s1 = calculate_sentence_log_prob(model, tokenizer, s1, device)
  log_prob_s2, ppl_s2 = calculate_sentence_log_prob(model, tokenizer, s2, device)

  data3.loc[index, "log(P(S1))"] = log_prob_s1
  data3.loc[index, "log(P(S2))"] = log_prob_s2

  if log_prob_s1 > log_prob_s2:
      data3.loc[index, "log(P(S1)) > log(P(S2))"] = 1
  else:
      data3.loc[index, "log(P(S1)) > log(P(S2))"] = 0
  data3.loc[index, "Confidence"] = abs(log_prob_s1 - log_prob_s2)
  data3.loc[index, "Ppl(S1)"] = ppl_s1
  data3.loc[index, "Ppl(S2)"] = ppl_s2

# %%
data3
# Out:
#              rows__row__sentence_good             rows__row__sentence_bad  \
# 0                I eat poha with tea                 I eat plate with tea
# 1                  I ordered a cycle                     I ordered a wall
# 2                    I gave him water                      I gave him air
# 3                     I eat a tablet                       I eat an ipad
# 4     I and he  drank coffee together  I and he drank coffee mug together
# 5  He has 10 lakh ruppes in his bank     He has 10 lakh cars  in his bank
# 6     He has calculator in his phone             He has car in his phone
#
#    log(P(S1))  log(P(S2))  log(P(S1)) > log(P(S2))  Confidence     Ppl(S1)  \
# 0  -42.390831  -38.279610                      0.0    4.111221  200.107330
# 1  -28.280740  -22.325230                      0.0    5.955510  286.044661
# 2  -24.987110  -26.826954                      1.0    1.839844  516.346233
# 3  -34.161522  -35.262740                      1.0    1.101218  927.325353
# 4  -43.304840  -46.841705                      1.0    3.536866  486.095768
# 5  -51.228065  -56.218821                      1.0    4.990756   38.828228
# 6  -42.809395  -44.947250                      1.0    2.137856  210.855772
#
#        Ppl(S2)
# 0  2113.122385
# 1   265.418390
# 2   817.898685
# 3   356.781431
# 4   349.049297
# 5   108.299627
# 6   614.639408

# %%
data3.to_csv("/kaggle/working/Self_curated_data_output.csv")

# %% [markdown]
# ### Testing on Reference Tracking Data

# %%
data4 = pd.read_csv("/kaggle/input/dataset/Reference_tracking_data.csv")

for index, row in data4.iterrows():
  s1 = row["rows__row__sentence_good"]         
  s2 = row["rows__row__sentence_bad"]   

  log_prob_s1, ppl_s1 = calculate_sentence_log_prob(model, tokenizer, s1, device)
  log_prob_s2, ppl_s2 = calculate_sentence_log_prob(model, tokenizer, s2, device)

  data4.loc[index, "log(P(S1))"] = log_prob_s1
  data4.loc[index, "log(P(S2))"] = log_prob_s2

  if log_prob_s1 > log_prob_s2:
      data4.loc[index, "log(P(S1)) > log(P(S2))"] = 1
  else:
      data4.loc[index, "log(P(S1)) > log(P(S2))"] = 0
  data4.loc[index, "Confidence"] = abs(log_prob_s1 - log_prob_s2)
  data4.loc[index, "Ppl(S1)"] = ppl_s1
  data4.loc[index, "Ppl(S2)"] = ppl_s2

# %%
data4
# Out:
#                              rows__row__sentence_good  \
# 0    Riya gave Anu a gift because she had a birthday.
# 1   Arjun called Kabir because he needed help with...
# 2          Meera hugged Sanya because she was crying.
# 3   The dog barked at the stranger because he ente...
# 4   Amit cleaned the table because it had food sta...
# 5   Tina put the book in the bag because it was to...
# 6   Rohan thanked Neeraj because he fixed the comp...
# 7   Priya covered the pot because it was boiling o...
# 8   The car hit the pole because it slipped on the...
# 9        Anita washed the spoon because it was dirty.
# 10  Aman moved the chair because it was blocking t...
# 11  Sneha closed the window because it was letting...
# 12  The wind shook the tree because it was strong ...
# 13  Kabir threw the ball because it slipped from h...
# 14            Ritu fed the cat because it was hungry.
# 15  The teacher scolded the student because he was...
# 16  Ayesha put the towel in the sun because it was...
# 17  Raghav carried the box because it was too heav...
# 18  The monkey dropped the fruit because it was sl...
# 19    Mehul stopped the bike because it was skidding.
# 20  The bottle broke the tile because it fell from...
# 21      Ria stitched the shirt because it had a tear.
# 22  The chef covered the pan because it was splash...
# 23  Lakshya pushed the trolley because it was bloc...
# 24   The candle melted the toy because it touched it.
# 25      Arnav mopped the floor because it was sticky.
# 26    Simran saved the file because it was important.
# 27        The child cried because the balloon popped.
# 28  Nisha opened the umbrella because it was raining.
# 29  The cup fell from the table because it was sha...
# 30    Rohan moved the lamp because it was flickering.
# 31  Aditi shifted the crate because it was blockin...
# 32  The ball rolled into the drain because it was ...
# 33  Sarthak moved the fan because it was too close...
# 34  The cat chased the mouse because it ran under ...
# 35  Meera pressed the button because it wasn’t wor...
# 36  The truck splashed the pedestrian because it w...
# 37  Karan covered the bowl because it was attracti...
# 38  The wind blew the papers because they were light.
# 39  Asha closed the drawer because it was sticking...
# 40  The mechanic fixed the bike because it had a l...
# 41  Piyush dried the bench because it was wet from...
# 42  The clock woke the child because it was too loud.
# 43  Sana pushed the trolley because it was blockin...
# 44  The dog avoided the bucket because it was slip...
# 45  Ananya folded the blanket because it was wrink...
# 46        The laptop shut down because it overheated.
# 47      Ravi cleaned the mirror because it was dusty.
# 48     The bus stopped because it reached the signal.
# 49  The bulb fused because it received a voltage s...
#
#                               rows__row__sentence_bad  log(P(S1))  log(P(S2))  \
# 0      Riya gave Anu a gift because she had a basket.  -55.073737  -65.548556
# 1   Arjun called Kabir because the project needed ...  -54.337789  -68.338420
# 2   Meera hugged Sanya because the hallway was cry...  -50.235772  -68.761339
# 3   The dog barked at the stranger because the gat...  -43.306327  -55.225323
# 4   Amit cleaned the table because the food stains...  -50.619358  -67.126022
# 5   Tina put the book in the bag because the bag w...  -51.264824  -57.534032
# 6   Rohan thanked Neeraj because the computer fixe...  -62.479733  -71.225389
# 7   Priya covered the pot because the boiling wate...  -49.779676  -64.463325
# 8   The car hit the pole because the pole slipped ...  -41.874022  -50.661323
# 9       Anita washed the spoon because she was dirty.  -45.292768  -51.623998
# 10  Aman moved the chair because the door was bloc...  -49.623013  -58.247206
# 11  Sneha closed the window because the dust was l...  -54.349290  -73.958588
# 12  The wind shook the tree because the tree was s...  -47.103800  -52.544008
# 13  Kabir threw the ball because his hand slipped ...  -49.853170  -56.493806
# 14      Ritu fed the cat because the food was hungry.  -46.893277  -60.743425
# 15  The teacher scolded the student because the cl...  -36.957438  -47.461792
# 16  Ayesha put the towel in the sun because the su...  -55.368717  -65.275676
# 17  Raghav carried the box because his sister was ...  -52.181758  -60.794127
# 18  The monkey dropped the fruit because the tree ...  -46.843633  -50.710570
# 19  Mehul stopped the bike because the road was sk...  -52.842985  -59.063578
# 20  The bottle broke the tile because the tile fel...  -52.135054  -56.690217
# 21  Ria stitched the shirt because the tear had a ...  -54.212872  -73.900927
# 22  The chef covered the pan because the oil was c...  -57.546381  -67.300970
# 23  Lakshya pushed the trolley because the exit wa...  -57.276417  -66.723663
# 24  The candle melted the toy because the toy touc...  -54.696114  -58.409575
# 25      Arnav mopped the floor because he was sticky.  -52.984916  -59.822984
# 26  Simran saved the file because the importance s...  -48.246145  -67.888191
# 27          The child cried because the child popped.  -34.891525  -46.949936
# 28  Nisha opened the umbrella because the rain ope...  -41.627635  -58.095721
# 29  The cup fell from the table because the table ...  -44.164537  -60.228496
# 30    Rohan moved the lamp because he was flickering.  -53.354709  -59.590192
# 31  Aditi shifted the crate because the path was b...  -55.553679  -67.077169
# 32  The ball rolled into the drain because the dra...  -51.978052  -55.375368
# 33  Sarthak moved the fan because the curtain was ...  -57.322617  -65.930550
# 34  The cat chased the mouse because the sofa ran ...  -47.932931  -69.301446
# 35  Meera pressed the button because she wasn’t wo...  -52.658489  -57.990043
# 36  The truck splashed the pedestrian because the ...  -57.282536  -67.397758
# 37  Karan covered the bowl because the flies were ...  -58.496698  -67.734718
# 38  The wind blew the papers because the wind was ...  -42.147498  -47.950245
# 39  Asha closed the drawer because she was stickin...  -57.509638  -62.590992
# 40  The mechanic fixed the bike because the chain ...  -46.194607  -61.082168
# 41  Piyush dried the bench because the rain dried ...  -56.947452  -64.945702
# 42  The clock woke the child because the child was...  -47.950728  -57.062347
# 43  Sana pushed the trolley because the aisle was ...  -55.787101  -63.350973
# 44  The dog avoided the bucket because the bucket ...  -48.720926  -52.685832
# 45  Ananya folded the blanket because she was wrin...  -51.601387  -57.983110
# 46  The laptop shut down because the table overhea...  -33.998725  -45.666927
# 47  Ravi cleaned the mirror because the dust clean...  -46.483244  -59.347675
# 48     The bus stopped because the signal reached it.  -43.129432  -49.149313
# 49  The bulb fused because the spike received a bulb.  -48.689288  -66.650197
#
#     log(P(S1)) > log(P(S2))  Confidence     Ppl(S1)     Ppl(S2)
# 0                       1.0   10.474819   51.102753  107.990120
# 1                       1.0   14.000631   48.485784  131.803965
# 2                       1.0   18.525568   96.244163  308.003639
# 3                       1.0   11.918996   27.973452   51.659076
# 4                       1.0   16.506664   67.916556  120.870035
# 5                       1.0    6.269208   24.632125   29.498955
# 6                       1.0    8.745657  122.257964  239.577298
# 7                       1.0   14.683648   63.326657   99.935321
# 8                       1.0    8.787301   25.055131   37.287790
# 9                       1.0    6.331229   92.691507  174.582912
# 10                      1.0    8.624193   62.505281  128.243886
# 11                      1.0   19.609298   37.460461  101.739104
# 12                      1.0    5.440208   72.396910   79.731708
# 13                      1.0    6.640635   63.715691   77.144275
# 14                      1.0   13.850148  108.780024  250.167210
# 15                      1.0   10.504353   21.753758   38.509580
# 16                      1.0    9.906959   52.190912   77.611200
# 17                      1.0    8.612369   32.420270   57.566557
# 18                      1.0    3.866937   36.721278   37.419186
# 19                      1.0    6.220592   81.743157   94.005391
# 20                      1.0    4.555164   77.060267   78.318666
# 21                      1.0   19.688055   91.628219  294.325607
# 22                      1.0    9.754589  120.968690  177.150147
# 23                      1.0    9.447247   35.865508   64.730271
# 24                      1.0    3.713461  144.369208  129.990912
# 25                      1.0    6.838068   58.895386   99.660361
# 26                      1.0   19.642046  124.538453  478.977559
# 27                      1.0   12.058411   48.271246  353.803611
# 28                      1.0   16.468086   24.584737   87.260826
# 29                      1.0   16.063959   55.420962   55.436213
# 30                      1.0    6.235483  127.795088  225.267866
# 31                      1.0   11.523491  102.460075  267.672473
# 32                      1.0    3.397316   76.058619  100.948856
# 33                      1.0    8.607933   35.969219   61.599845
# 34                      1.0   21.368515   39.930825  141.189546
# 35                      1.0    5.331554   57.434949   86.554348
# 36                      1.0   10.115223   35.879226   42.280243
# 37                      1.0    9.238019  130.938123  183.160517
# 38                      1.0    5.802747   67.677232   78.187768
# 39                      1.0    5.081354  186.447358  295.920305
# 40                      1.0   14.887561   34.932977   58.682673
# 41                      1.0    7.998250   58.420982  224.111075
# 42                      1.0    9.111619   78.191198  116.186379
# 43                      1.0    7.563872   41.228924   68.265070
# 44                      1.0    3.964906   57.978786   57.555880
# 45                      1.0    6.381723   73.708313  125.452333
# 46                      1.0   11.668202   29.960281   63.531691
# 47                      1.0   12.864430   68.425769  220.355724
# 48                      1.0    6.019881  120.561390  235.340823
# 49                      1.0   17.960909   42.322965  116.830990

# %%
data4.to_csv("/kaggle/working/Reference_tracking_data_output.csv")

# %%
model.eval()
print("model_type:", getattr(model.config, "model_type", None), "class:", type(model))
# Out:
# model_type: mistral class: <class 'transformers.models.mistral.modeling_mistral.MistralForCausalLM'>
